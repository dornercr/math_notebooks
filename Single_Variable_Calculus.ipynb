# %% [markdown]
# <a href="https://colab.research.google.com/github/dornercr/math_notebooks/blob/main/Single_Variable_Calculus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Derivatives Study Guide
#
# ## Overview
#
# This unit introduces derivatives, their geometric and physical interpretations, their importance in real-world applications, and how to compute them using fundamental calculus concepts.
#
# ---
#
# ## I. What is a Derivative?
#
# ### A. Definitions and Interpretations
#
# - **Geometric Interpretation**: Slope of the tangent line to a graph at a point
# - **Physical Interpretation**: Instantaneous rate of change (e.g., velocity)
# - **Real-World Importance**: Used in science, engineering, economics, political science, etc.
#
# ### B. Key Idea
#
# - The derivative at a point is:
#
# $$
# f'(x) = \lim_{h \to 0} \frac{f(x+h) - f(x)}{h}
# $$
#
# ---
#
# ## II. Geometric Interpretation: Tangent Line
#
# ### A. Tangent vs. Secant Line
#
# - **Tangent line**: touches the graph at one point without crossing it
# - **Secant line**: passes through two points on the graph
#
# - Slope of the secant line:
#
# $$
# m_{\text{secant}} = \frac{f(x + h) - f(x)}{h}
# $$
#
# ### B. Tangent Slope as a Limit
#
# - As \( h \to 0 \), the secant becomes the tangent
# - Slope of tangent line:
#
# $$
# m_{\text{tangent}} = \lim_{h \to 0} \frac{f(x + h) - f(x)}{h}
# $$
#
# ---
#
# ## III. Derivative Calculation
#
# ### A. Using Difference Quotient
#
# $$
# \frac{f(x + h) - f(x)}{h}
# $$
#
# - Divide by \( h \) and simplify
#
# ### B. Interpretation
#
# - **Negative slope**: decreasing function
# - As \( h \to 0 \): slope magnitude increases or decreases depending on behavior
#
# ---
#
# ## IV. Applied Word Problem: Area Under a Tangent Line
#
# ### A. Problem
#
# Find area of triangle formed by:
# - Axes
# - Tangent line to \( f(x) \)
#
# ### B. Tangent Line Equation
#
# At point \( (x_0, f(x_0)) \):
#
# $$
# y - f(x_0) = f'(x_0)(x - x_0)
# $$
#
# ### C. Solving for Intercepts
#
# - **x-intercept**: Set \( y = 0 \) and solve for \( x \)
# - **y-intercept**: By symmetry, computed from equation
#
# ### D. Area Calculation
#
# - Triangle Area:
#
# $$
# A = \frac{1}{2} \cdot x \cdot y
# $$
#
# - Constant area regardless of \( x \) — specific to \( f(x) \) form
#
# ---
#
# ## V. Notation for Derivatives
#
# ### A. Common Notations
#
# - \( f'(x) \) (Newton's notation)
# - \( \frac{dy}{dx} \) (Leibniz notation)
#
# ### B. Interpretation
#
# - All mean the same: the derivative of a function
# - Be aware of context when variables are reused (e.g., \( y \) as function and coordinate)
#
# ---
#
# ## VI. Derivative Derivation (Example)
#
# ### A. Difference Quotient
#
# $$
# \frac{f(x+h) - f(x)}{h}
# $$
#
# ### B. Binomial Expansion
#
# Expand polynomial terms if needed
#
# ### C. Take the Limit
#
# Evaluate limit as \( h \to 0 \)
#
# ### D. Extension to Polynomials
#
# Apply to all power terms in the function
#
# ---
#
# ## VII. Final Remarks
#
# ### A. Conceptual Complexity
#
# - One-variable calculus involves juggling many variables (e.g., \( x \), \( h \))
# - Variable roles change based on context — use careful notation and interpretation
#
# ### B. Common Confusion
#
# - Variable reuse (e.g., \( f \) as function vs. value)
# - Be explicit and organized in computations
#
# ---
#
# ## Summary: Key Formulas
#
# - **Definition of Derivative**:
# $$
# f'(x) = \lim_{h \to 0} \frac{f(x+h) - f(x)}{h}
# $$
#
# - **Power Rule**:
# $$
# \frac{d}{dx}(x^n) = nx^{n-1}
# $$
#
# - **Tangent Line Equation**:
# $$
# y - f(x_0) = f'(x_0)(x - x_0)
# $$
#
# ---
#
# ## Practice Recommendations
#
# - Apply derivative rules to various functions
# - Use the geometric approach to visualize tangent lines
# - Practice difference quotients for different types of functions
# - Solve application problems involving tangents and area

# %%
import sympy as sp

# Setup
x, h = sp.symbols('x h')
f = (2*x**3 + 1) * (x**2 - 4)
f_x_h = f.subs(x, x + h)
difference_quotient = (f_x_h - f) / h
derivative = sp.limit(difference_quotient, h, 0)

# Plain text with ** formatting
print(f"The derivative is {derivative}\n")
print("🧮 Step-by-Step Derivative")
print("-" * 50)
print("f(x)         = {}".format(f))
print("f(x + h)     = {}".format(f_x_h))
print("Quotient     = ({}) / h".format(f_x_h - f))
print("Final f'(x)  = {}".format(derivative))
# Out:
# The derivative is 10*x**4 - 24*x**2 + 2*x
#
# 🧮 Step-by-Step Derivative
# --------------------------------------------------
# f(x)         = (x**2 - 4)*(2*x**3 + 1)
# f(x + h)     = ((h + x)**2 - 4)*(2*(h + x)**3 + 1)
# Quotient     = (-(x**2 - 4)*(2*x**3 + 1) + ((h + x)**2 - 4)*(2*(h + x)**3 + 1)) / h
# Final f'(x)  = 10*x**4 - 24*x**2 + 2*x

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define symbol
x = sp.Symbol('x')

# Define the function
f_expr = f

# Compute derivative
f_prime_expr = derivative

# Convert to numerical functions
f = sp.lambdify(x, f_expr, modules=['numpy'])
f_prime = sp.lambdify(x, f_prime_expr, modules=['numpy'])

# X range
x_vals = np.linspace(-5, 5, 400)
y_vals = f(x_vals)
y_prime_vals = f_prime(x_vals)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(x_vals, y_vals, label='f(x)', color='blue')
plt.plot(x_vals, y_prime_vals, label="f'(x)", color='red', linestyle='--')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title('Function and Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()
